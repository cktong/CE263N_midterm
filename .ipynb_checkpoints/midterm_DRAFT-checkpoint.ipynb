# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn

# %matplotlib inline

file = open('housing_midterm_trn.csv', 'rb')
data = np.genfromtxt(file, delimiter=',',skip_header=1)

#print(data, data.shape)

x = data[:,0:20]
y = data[:,-1]

# %%
c= ['longitude', 'latitude', 'yrbuilt', 'stories_code', 
    'TLA', 'Wall_code', 'beds', 'baths', 'halfbaths', 'frontage', 
    'garage_type_code', 'garage_sqft', 'rooms', 'lotsize', 'sale_date', 
    'sold93', 'sold94', 'sold95', 'sold96', 'sold97', 'sold98', 'price']


train_data= pd.DataFrame(data, columns = c)

# %%
train_data.query('sold98 == 1').describe()
# Out:
#          longitude     latitude      yrbuilt  stories_code          TLA  \
# count  3514.000000  3514.000000  3514.000000    3514.00000  3514.000000
# mean    -83.601058    41.659014  1944.075982       2.70148  1423.739044
# std       0.080224     0.044770    27.408958       1.83413   589.035775
# min     -83.882392    41.435758  1850.000000       1.00000   400.000000
# 25%     -83.645794    41.631095  1923.000000       1.00000  1055.250000
# 50%     -83.601427    41.665695  1949.000000       1.00000  1292.000000
# 75%     -83.553187    41.693668  1962.000000       5.00000  1620.000000
# max     -83.248541    41.731639  1997.000000       7.00000  6074.000000
#
#          Wall_code         beds        baths    halfbaths     frontage  \
# count  3514.000000  3514.000000  3514.000000  3514.000000  3514.000000
# mean      5.337507     2.950768     1.210302     0.307342    62.043540
# std       1.502983     0.715109     0.466219     0.481384    41.125506
# ...

# %%
# Importance of Location 

plt.figure(figsize=(18,12))

price = y
price[price>300000]= 300000

plt.scatter(x[:,0], x[:,1], s=10, c=price, alpha = 0.2, edgecolors='none')

plt.colorbar()

# %%
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

price = y
price[price>300000]= 300000

c= ['longitude', 'latitude', 'yrbuilt', 'stories_code', 
    'TLA', 'Wall_code', 'beds', 'baths', 'frontage', 
    'garage_type_code', 'garage_sqft', 'rooms', 'lotsize', 'sale_date']

features= train_data[c].as_matrix()

#features= train_data[['longitude', 'latitude','rooms', 'TLA','yrbuilt','price']].query('price <200000').as_matrix()
#price = list(features.transpose()).pop(-1)

pca = LinearDiscriminantAnalysis(n_components=2)
X_r = pca.fit(features,price).transform(features)

plt.figure(figsize=(18,12))
plt.scatter(X_r[:,0], X_r[:,1], s=10, c=price, alpha = 0.5, edgecolors='none')
plt.colorbar()

'''
xmin=-5
xmax=5
ymin= -2
ymax=2
plt.axis([xmin,xmax,ymin,ymax])
'''
# Out:
# '\nxmin=-5\nxmax=5\nymin= -2\nymax=2\nplt.axis([xmin,xmax,ymin,ymax])\n'

# %%
pca.predict()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-00f54cf4b497> in <module>()
# ----> 1 pca.predict()
#
# TypeError: predict() takes exactly 2 arguments (1 given)

# %%
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from mpl_toolkits.mplot3d import Axes3D

features= train_data.as_matrix()

pca = LinearDiscriminantAnalysis(n_components=3)
X_r = pca.fit(features,price).transform(features)

fig=plt.figure(figsize=(18,12))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X_r[:,0], X_r[:,1], zs=X_r[:,2], s=5, c=price, alpha = 0.5, edgecolors='none')
#ax.colorbar()

'''
xmin=-5
xmax=5
ymin= -2
ymax=2
plt.axis([xmin,xmax,ymin,ymax])
'''
# Out:
# '\nxmin=-5\nxmax=5\nymin= -2\nymax=2\nplt.axis([xmin,xmax,ymin,ymax])\n'

# %% [markdown]
# ### CrossValidate

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold

kf = KFold(n_splits=5)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-232-5b1a79d054dc> in <module>()
#       1 from sklearn.metrics import mean_squared_error
# ----> 2 from sklearn.model_selection import KFold
#       3
#       4 kf = KFold(n_splits=5)
#
# ImportError: No module named model_selection

# %%
from sklearn.model_selection import KFold
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-241-7748d201c9c6> in <module>()
# ----> 1 from sklearn.model_selection import KFold
#
# ImportError: No module named model_selection
